# %% [markdown]
# ## The goal for this project is to analyze data to help "developers" understand what type of apps are likely to attract more users.

# %%
import pandas as pd
import numpy as np
googleapps = pd.read_csv('./resources/googleplaystore.csv')

# %%
googleapps.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
googleapps['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# 1.9                       1
# Name: Category, dtype: int64

# %%
googleapps.Price.value_counts()
# Out:
# 0         10040
# $0.99       148
# $2.99       129
# $1.99        73
# $4.99        72
#           ...
# $15.99        1
# $25.99        1
# $4.29         1
# $2.95         1
# $1.96         1
# Name: Price, Length: 93, dtype: int64

# %% [markdown]
# ### Pt. - IIa Investigate the 1.9 in "Category" column

# %%
googleapps.loc[10470:10474]
# Out:
#                                            App         Category  Rating  \
# 10470                               Jazz Wi-Fi    COMMUNICATION     3.4
# 10471                         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5
# 10472  Life Made WI-Fi Touchscreen Photo Frame              1.9    19.0
# 10473                  osmino Wi-Fi: free WiFi            TOOLS     4.2
# 10474                             Sat-Fi Voice    COMMUNICATION     3.4
#
#       Reviews    Size     Installs  Type     Price Content Rating  \
# 10470      49    4.0M      10,000+  Free         0       Everyone
# 10471    1042    404k     100,000+  Free         0       Everyone
# 10472    3.0M  1,000+         Free     0  Everyone            NaN
# 10473  134203    4.1M  10,000,000+  Free         0       Everyone
# 10474      37     14M       1,000+  Free         0       Everyone
#
#                   Genres       Last Updated Current Ver   Android Ver
# 10470      Communication  February 10, 2017         0.1    2.3 and up
# 10471    Personalization     August 5, 2014       3.0.0  4.0.3 and up
# 10472  February 11, 2018             1.0.19  4.0 and up           NaN
# 10473              Tools     August 7, 2018     6.06.14    4.4 and up
# 10474      Communication  November 21, 2014     2.2.1.5    2.2 and up

# %% [markdown]
# ### ...it is missing a category data. Let us delete the row entirely.

# %%
googleapps.drop([10472], inplace=True)

# %%
googleapps.loc[10470:10474]
# Out:
#                            App         Category  Rating Reviews  Size  \
# 10470               Jazz Wi-Fi    COMMUNICATION     3.4      49  4.0M
# 10471         Xposed Wi-Fi-Pwd  PERSONALIZATION     3.5    1042  404k
# 10473  osmino Wi-Fi: free WiFi            TOOLS     4.2  134203  4.1M
# 10474             Sat-Fi Voice    COMMUNICATION     3.4      37   14M
#
#           Installs  Type Price Content Rating           Genres  \
# 10470      10,000+  Free     0       Everyone    Communication
# 10471     100,000+  Free     0       Everyone  Personalization
# 10473  10,000,000+  Free     0       Everyone            Tools
# 10474       1,000+  Free     0       Everyone    Communication
#
#             Last Updated Current Ver   Android Ver
# 10470  February 10, 2017         0.1    2.3 and up
# 10471     August 5, 2014       3.0.0  4.0.3 and up
# 10473     August 7, 2018     6.06.14    4.4 and up
# 10474  November 21, 2014     2.2.1.5    2.2 and up

# %% [markdown]
# ### Pt. IIb - Searching for duplicates

# %%
googleapps['App'].duplicated().value_counts()
# Out:
# False    9659
# True     1181
# Name: App, dtype: int64

# %%
duplicate_gApps = googleapps[googleapps['App'].duplicated()].copy()

# %%
duplicate_gApps['App'].value_counts()
# Out:
# ROBLOX                                               8
# CBS Sports App - Scores, News, Stats & Watch Live    7
# 8 Ball Pool                                          6
# ESPN                                                 6
# Duolingo: Learn Languages Free                       6
#                                                     ..
# Digit Save Money Automatically                       1
# All Social Networks                                  1
# Google Translate                                     1
# PBS KIDS Video                                       1
# Fruits Bomb                                          1
# Name: App, Length: 798, dtype: int64

# %%
duplicate_gApps[duplicate_gApps.App == 'Instagram']
# Out:
#             App Category  Rating   Reviews                Size  \
# 2604  Instagram   SOCIAL     4.5  66577446  Varies with device
# 2611  Instagram   SOCIAL     4.5  66577313  Varies with device
# 3909  Instagram   SOCIAL     4.5  66509917  Varies with device
#
#             Installs  Type Price Content Rating  Genres   Last Updated  \
# 2604  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 2611  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 3909  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
#
#              Current Ver         Android Ver
# 2604  Varies with device  Varies with device
# 2611  Varies with device  Varies with device
# 3909  Varies with device  Varies with device

# %%
googleapps[googleapps.App.str.contains('Facebook')].head(8)
# Out:
#                                                     App  Category  Rating  \
# 201                              Facebook Pages Manager  BUSINESS     4.0
# 215                                Facebook Ads Manager  BUSINESS     4.1
# 2544                                           Facebook    SOCIAL     4.1
# 2546                                      Facebook Lite    SOCIAL     4.3
# 2561  Who Viewed My Facebook Profile - Stalkers Visi...    SOCIAL     4.6
# 2572                                     Facebook Local    SOCIAL     4.2
# 2577                       HTC Social Plugin - Facebook    SOCIAL     3.6
# 3943                                           Facebook    SOCIAL     4.1
#
#        Reviews                Size        Installs  Type Price Content Rating  \
# 201    1279184  Varies with device     50,000,000+  Free     0       Everyone
# 215      19023  Varies with device      1,000,000+  Free     0       Everyone
# 2544  78158306  Varies with device  1,000,000,000+  Free     0           Teen
# 2546   8606259  Varies with device    500,000,000+  Free     0           Teen
# 2561    271445                9.9M      5,000,000+  Free     0       Everyone
# 2572      4751  Varies with device      1,000,000+  Free     0           Teen
# 2577     13223                2.8M     10,000,000+  Free     0     Mature 17+
# 3943  78128208  Varies with device  1,000,000,000+  Free     0           Teen
#
#         Genres    Last Updated         Current Ver         Android Ver
# 201   Business  August 2, 2018  Varies with device  Varies with device
# 215   Business  August 1, 2018        99.0.0.35.75          4.1 and up
# 2544    Social  August 3, 2018  Varies with device  Varies with device
# 2546    Social  August 1, 2018  Varies with device  Varies with device
# 2561    Social   June 24, 2018               4.1.1        4.0.3 and up
# 2572    Social   June 30, 2018                13.0          4.1 and up
# 2577    Social    June 8, 2016         8.00.752746          4.4 and up
# 3943    Social  August 3, 2018  Varies with device  Varies with device

# %%
print(googleapps.loc[3943])
# Out:
# App                         Facebook
# Category                      SOCIAL
# Rating                           4.1
# Reviews                     78128208
# Size              Varies with device
# Installs              1,000,000,000+
# Type                            Free
# Price                              0
# Content Rating                  Teen
# Genres                        Social
# Last Updated          August 3, 2018
# Current Ver       Varies with device
# Android Ver       Varies with device
# Name: 3943, dtype: object

# %%
googleapps.loc[2544]
# Out:
# App                         Facebook
# Category                      SOCIAL
# Rating                           4.1
# Reviews                     78158306
# Size              Varies with device
# Installs              1,000,000,000+
# Type                            Free
# Price                              0
# Content Rating                  Teen
# Genres                        Social
# Last Updated          August 3, 2018
# Current Ver       Varies with device
# Android Ver       Varies with device
# Name: 2544, dtype: object

# %% [markdown]
# ### Pt. IIb - Pulling a sample of the duplicates to test our methodology – remove all duplicates except the one with the most amount of ratings

# %% [markdown]
# #### Let us remind ourselves how many duplicates there are 🤔

# %%
googleapps['App'].duplicated().value_counts()
# Out:
# False    9659
# True     1181
# Name: App, dtype: int64

# %% [markdown]
# ### Pt. IIc - Testing our methodolody for removing duplicates

# %%
ig = googleapps[googleapps.App == 'Instagram'].copy()

# %%
ig.duplicated(subset='App')
# Out:
# 2545    False
# 2604     True
# 2611     True
# 3909     True
# dtype: bool

# %%
ig
# Out:
#             App Category  Rating   Reviews                Size  \
# 2545  Instagram   SOCIAL     4.5  66577313  Varies with device
# 2604  Instagram   SOCIAL     4.5  66577446  Varies with device
# 2611  Instagram   SOCIAL     4.5  66577313  Varies with device
# 3909  Instagram   SOCIAL     4.5  66509917  Varies with device
#
#             Installs  Type Price Content Rating  Genres   Last Updated  \
# 2545  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 2604  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 2611  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 3909  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
#
#              Current Ver         Android Ver
# 2545  Varies with device  Varies with device
# 2604  Varies with device  Varies with device
# 2611  Varies with device  Varies with device
# 3909  Varies with device  Varies with device

# %%
ig.sort_values(by=['Reviews'], inplace=True, ascending=False) #sort values by Reviews so the highest number of values for a particular set of duplicates rises to the top.
ig
# Out:
#             App Category  Rating   Reviews                Size  \
# 2604  Instagram   SOCIAL     4.5  66577446  Varies with device
# 2545  Instagram   SOCIAL     4.5  66577313  Varies with device
# 2611  Instagram   SOCIAL     4.5  66577313  Varies with device
# 3909  Instagram   SOCIAL     4.5  66509917  Varies with device
#
#             Installs  Type Price Content Rating  Genres   Last Updated  \
# 2604  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 2545  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 2611  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
# 3909  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
#
#              Current Ver         Android Ver
# 2604  Varies with device  Varies with device
# 2545  Varies with device  Varies with device
# 2611  Varies with device  Varies with device
# 3909  Varies with device  Varies with device

# %%
ig.drop_duplicates(subset=['App'],keep='first', inplace=True) #Then drop all duplicates except the very first one.

# %%
ig
# Out:
#             App Category  Rating   Reviews                Size  \
# 2604  Instagram   SOCIAL     4.5  66577446  Varies with device
#
#             Installs  Type Price Content Rating  Genres   Last Updated  \
# 2604  1,000,000,000+  Free     0           Teen  Social  July 31, 2018
#
#              Current Ver         Android Ver
# 2604  Varies with device  Varies with device

# %% [markdown]
# ### Pt. IIIa - Applying our methodology to the dataframe

# %%
googleapps.sort_values(by=['Reviews'], inplace=True, ascending=False)

# %%
googleapps.drop_duplicates(subset=['App'], keep='first', inplace=True)

# %% [markdown]
# #### Now let us check how many duplicates there are after applying our methodology

# %%
googleapps['App'].duplicated().value_counts()
# Out:
# False    9659
# Name: App, dtype: int64

# %% [markdown]
# #### Huzzah! 🙌 zero duplicates! But let us run some tests just to be sure

# %%
googleapps[googleapps.App == 'ROBLOX']
# Out:
#          App Category  Rating  Reviews Size      Installs  Type Price  \
# 2206  ROBLOX   FAMILY     4.5  4450890  67M  100,000,000+  Free     0
#
#      Content Rating                        Genres   Last Updated  \
# 2206   Everyone 10+  Adventure;Action & Adventure  July 31, 2018
#
#        Current Ver Android Ver
# 2206  2.347.225742  4.1 and up

# %%
googleapps.App.value_counts()
# Out:
# Escaping the Prison                                1
# HAWK – Force of an Arcade Shooter. Shoot 'em up    1
# Gboard - the Google Keyboard                       1
# Financial Calculator India                         1
# Cathy AH                                           1
#                                                   ..
# Guardians of Ancora                                1
# ZOOKEEPER DX TouchEdition                          1
# PulsePoint AED                                     1
# Word Link                                          1
# Fame Boom for Real Followers, Likes                1
# Name: App, Length: 9659, dtype: int64

# %% [markdown]
# ### Pt. IVa - More cleaning: filtering out non-English characters

# %%
googleapps[googleapps['App'].map(lambda x: x.isascii())]
# Out:
#                                     App          Category  Rating Reviews  \
# 2989             GollerCepte Live Score            SPORTS     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT             TOOLS     3.3     999
# 2723                SnipSnap Coupon App          SHOPPING     4.2    9975
# 3079  US Open Tennis Championships 2018            SPORTS     4.0    9971
# 3229                         DreamTrips  TRAVEL_AND_LOCAL     4.7    9971
# ...                                 ...               ...     ...     ...
# 2465                  ear super hearing           MEDICAL     NaN       0
# 9925                      Reisedealz.eu            SOCIAL     NaN       0
# 9928                        EU Whoiswho          BUSINESS     NaN       0
# 9929     EU Brazil Green Business Forum      PRODUCTIVITY     NaN       0
# 7101                 Register.ca Mobile      PRODUCTIVITY     NaN       0
#
#       Size    Installs  Type Price Content Rating          Genres  \
# 2989   31M  1,000,000+  Free     0       Everyone          Sports
# 4970   91k    100,000+  Free     0       Everyone           Tools
# 2723   18M  1,000,000+  Free     0       Everyone        Shopping
# 3079   33M  1,000,000+  Free     0       Everyone          Sports
# 3229   22M    500,000+  Free     0           Teen  Travel & Local
# ...    ...         ...   ...   ...            ...             ...
# 2465  1.4M          5+  Free     0       Everyone         Medical
# 9925   10M         10+  Free     0       Everyone          Social
# 9928  2.7M         10+  Free     0       Everyone        Business
# 9929  8.7M         10+  Free     0       Everyone    Productivity
# 7101  1.2M        100+  Free     0       Everyone    Productivity
#
#             Last Updated            Current Ver Android Ver
# 2989        May 23, 2018                    6.5  4.1 and up
# 4970   December 17, 2013                    3.2  2.2 and up
# 2723    January 22, 2018                    1.4  4.3 and up
# 3079        June 5, 2018                    7.1  5.0 and up
# 3229      August 6, 2018                 1.28.1  5.0 and up
# ...                  ...                    ...         ...
# 2465       July 31, 2018  1.0 Super Ear Hearing  4.0 and up
# 9925  September 24, 2015                    1.0  4.0 and up
# 9928    December 1, 2016                  0.0.1  4.0 and up
# 9929      April 18, 2017                  1.7.1  2.1 and up
# 7101     August 19, 2016                    2.0  5.0 and up
#
# [9117 rows x 13 columns]

# %%
googleapps[googleapps['App'].str.contains('爱奇')]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
len(googleapps)
# Out:
# 9659

# %% [markdown]
# #### Now that we have only data with English characters, we will filter the data once more to look at free apps versus paid apps

# %% [markdown]
# ### Pt. Va - Isolating free apps

# %%
free_gapps = googleapps[googleapps['Price'] == 0].copy()

# %%
free_gapps
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
googleapps.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %% [markdown]
# ### Pt. Vb - oops the Price column is an object data type, we'll need too change it to a float

# %%
googleapps['Price'] = googleapps['Price'].str.replace('$', '').astype(float) #replace dollar signs with nothing, then switch dtype to floats

# %%
free_gapps = googleapps[googleapps['Price'] == 0].copy()
free_gapps.head()
# Out:
#                                     App          Category  Rating Reviews  \
# 2989             GollerCepte Live Score            SPORTS     4.2    9992
# 4970       Ad Block REMOVER - NEED ROOT             TOOLS     3.3     999
# 2723                SnipSnap Coupon App          SHOPPING     4.2    9975
# 3079  US Open Tennis Championships 2018            SPORTS     4.0    9971
# 3229                         DreamTrips  TRAVEL_AND_LOCAL     4.7    9971
#
#      Size    Installs  Type  Price Content Rating          Genres  \
# 2989  31M  1,000,000+  Free    0.0       Everyone          Sports
# 4970  91k    100,000+  Free    0.0       Everyone           Tools
# 2723  18M  1,000,000+  Free    0.0       Everyone        Shopping
# 3079  33M  1,000,000+  Free    0.0       Everyone          Sports
# 3229  22M    500,000+  Free    0.0           Teen  Travel & Local
#
#            Last Updated Current Ver Android Ver
# 2989       May 23, 2018         6.5  4.1 and up
# 4970  December 17, 2013         3.2  2.2 and up
# 2723   January 22, 2018         1.4  4.3 and up
# 3079       June 5, 2018         7.1  5.0 and up
# 3229     August 6, 2018      1.28.1  5.0 and up

# %% [markdown]
# #### How many free apps are there in the data?

# %%
free_gapps['Price'].value_counts()
# Out:
# 0.0    8903
# Name: Price, dtype: int64

# %% [markdown]
# #### and how many free apps are there in the original dataframe?

# %%
googleapps['Price'].value_counts()
# Out:
# 0.00      8903
# 0.99       145
# 2.99       124
# 1.99        73
# 4.99        70
#           ...
# 299.99       1
# 154.99       1
# 1.59         1
# 46.99        1
# 400.00       1
# Name: Price, Length: 92, dtype: int64

# %% [markdown]
# #### Sweet, our math checks out 😎

# %% [markdown]
# ### Pt. VIa - analyzing free apps on the Google Play store to see which Categories and Genres are the most common

# %%
free_gapps['Category'].value_counts().head()
# Out:
# FAMILY       1693
# GAME          861
# TOOLS         750
# BUSINESS      408
# LIFESTYLE     350
# Name: Category, dtype: int64

# %%
free_gapps['Genres'].value_counts().head()
# Out:
# Tools            749
# Entertainment    542
# Education        480
# Business         408
# Lifestyle        349
# Name: Genres, dtype: int64

# %%
free_gapps_category = free_gapps.groupby(['Category'])['App'].agg(total='count').reset_index()
free_gapps_category.sort_values('total', ascending=False).head()
# Out:
#      Category  total
# 11     FAMILY   1693
# 14       GAME    861
# 29      TOOLS    750
# 4    BUSINESS    408
# 18  LIFESTYLE    350

# %%
free_gapps['Reviews'] = free_gapps['Reviews'].astype(float)

# %%
free_gapps[free_gapps['Category'].str.contains('family|gaming|tools', case=False)].sort_values('Reviews', ascending=False).head(15)[['App','Category','Size','Rating','Reviews','Installs']]
# Out:
#                                                      App Category  \
# 4005             Clean Master- Space Cleaner & Antivirus    TOOLS
# 7536   Security Master - Antivirus, VPN, AppLock, Boo...    TOOLS
# 4568     360 Security - Free Antivirus, Booster, Cleaner    TOOLS
# 8896   DU Battery Saver - Battery Charger & Battery Life    TOOLS
# 8894   Cache Cleaner-DU Speed Booster (booster & clea...    TOOLS
# 2050            Minion Rush: Despicable Me Official Game   FAMILY
# 3975                                             Hay Day   FAMILY
# 7550   Battery Doctor-Battery Life Saver & Battery Co...    TOOLS
# 3234                                              Google    TOOLS
# 3255                          SHAREit - Transfer & Share    TOOLS
# 10186                                   Farm Heroes Saga   FAMILY
# 5856                                   Google Play Games   FAMILY
# 8439                      Duolingo: Learn Languages Free   FAMILY
# 5695             AVG AntiVirus 2018 for Android Security    TOOLS
# 3235                                    Google Translate    TOOLS
#
#                      Size  Rating     Reviews        Installs
# 4005   Varies with device     4.7  42916526.0    500,000,000+
# 7536   Varies with device     4.7  24900999.0    500,000,000+
# 4568   Varies with device     4.6  16771865.0    100,000,000+
# 8896                  14M     4.5  13479633.0    100,000,000+
# 8894                  15M     4.5  12759815.0    100,000,000+
# 2050   Varies with device     4.5  10216997.0    100,000,000+
# 3975                  94M     4.5  10053186.0    100,000,000+
# 7550                  17M     4.5   8190074.0    100,000,000+
# 3234   Varies with device     4.4   8033493.0  1,000,000,000+
# 3255                  17M     4.6   7790693.0    500,000,000+
# 10186                 71M     4.4   7615646.0    100,000,000+
# 5856   Varies with device     4.3   7168735.0  1,000,000,000+
# 8439   Varies with device     4.7   6297590.0    100,000,000+
# 5695   Varies with device     4.5   6207063.0    100,000,000+
# 3235   Varies with device     4.4   5745093.0    500,000,000+

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### In closing, based on the data analysis that we have just done and the table right above, I recommend an app profile that is either family, gaming or tool related.
